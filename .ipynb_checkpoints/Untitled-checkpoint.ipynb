# %%
import chess
import chess.svg
import time 
from random import randint
from IPython.display import display, Image
board = chess.Board()

chess.svg.piece(chess.Piece.from_symbol("R"))
legal_moves = list(board.legal_moves)

# print(board.legal_moves)
chess.svg.board(board,size=350)
# Out:
# '<svg xmlns="http://www.w3.org/2000/svg" version="1.1" xmlns:xlink="http://www.w3.org/1999/xlink" viewBox="0 0 400 400" width="350" height="350"><defs><g id="white-pawn" class="white pawn"><path d="M22 9c-2.21 0-4 1.79-4 4 0 .89.29 1.71.78 2.38-1.95 1.12-3.28 3.21-3.28 5.62 0 2.03.94 3.84 2.41 5.03-3 1.06-7.41 5.55-7.41 13.47h23c0-7.92-4.41-12.41-7.41-13.47 1.47-1.19 2.41-3 2.41-5.03 0-2.41-1.33-4.5-3.28-5.62.49-.67.78-1.49.78-2.38 0-2.21-1.79-4-4-4z" fill="#fff" stroke="#000" stroke-width="1.5" stroke-linecap="round" /></g><g id="white-knight" class="white knight" fill="none" fill-rule="evenodd" stroke="#000" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"><path d="M 22,10 C 32.5,11 38.5,18 38,39 L 15,39 C 15,30 25,32.5 23,18" style="fill:#ffffff; stroke:#000000;" /><path d="M 24,18 C 24.38,20.91 18.45,25.37 16,27 C 13,29 13.18,31.34 11,31 C 9.958,30.06 12.41,27.96 11,28 C 10,28 11.19,29.23 10,30 C 9,30 5.997,31 6,26 C 6,24 12,14 12,14 C 12,14 13.89,12.1 14,10.5 C 
# ...

# %%
print(legal_moves[0] )
move = chess.Move.from_uci(str(legal_moves[0]))
board.push(move)
chess.svg.board(board, size=350)
# Out:
# g1h3
# ...

# %%
legal_moves = list(board.legal_moves)
print(legal_moves[0] )
move = chess.Move.from_uci(str(legal_moves[0]))
board.push(move)
chess.svg.board(board, size=350)
# Out:
# g8h6
# ...

# %%
legal_moves = list(board.legal_moves)
print(legal_moves[0] )
move = chess.Move.from_uci(str(legal_moves[0]))
board.push(move)
chess.svg.board(board, size=350)
# Out:
# h3g5
# ...

# %%
legal_moves = list(board.legal_moves)
print(legal_moves[0] )
move = chess.Move.from_uci(str(legal_moves[0]))
board.push(move)
chess.svg.board(board, size=350)
# Out:
# h8g8
# ...

# %%
legal_moves = list(board.legal_moves)
print(legal_moves[0] )
move = chess.Move.from_uci(str(legal_moves[0]))
board.push(move)
chess.svg.board(board, size=350)
# Out:
# g5h7
# ...

# %%
while(True):
    legal_moves = list(board.legal_moves)
#     print(legal_moves[0] )
    move = chess.Move.from_uci(
        str(legal_moves[randint(0, len(legal_moves)-1)]))
    board.push(move)
#     print(legal_moves[0])
#     time.sleep(1)
    display(board)
# Out:
# f5f6
# Board('2r2r2/1np1n1pp/Pp1P1b1k/p3pR2/7P/P4Pq1/2NPP3/2RK3B b - - 0 37')
# f8h8
# Board('2r2r2/1np1n1pp/Pp1P1b1k/p3pRq1/7P/P4P2/2NPP3/2RK3B w - - 1 38')
# f5f6
# Board('2r2r2/1np1n1pp/Pp1P1b1k/p3pRq1/7P/P3PP2/2NP4/2RK3B b - - 0 38')
# f8h8
# Board('2r2r2/1np3pp/Pp1P1b1k/p2npRq1/7P/P3PP2/2NP4/2RK3B w - - 1 39')
# f5f6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-7d855be46a74> in <module>
#       6     board.push(move)
#       7     print(legal_moves[0])
# ----> 8     time.sleep(3)
#       9     display(board)
#
# KeyboardInterrupt:
